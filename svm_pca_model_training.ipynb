# %%
# %matplotlib inline

# %% [markdown]
# # Websites recognition example using eigenWebsites and SVMs

# %%
from time import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.utils.fixes import loguniform

# %% [markdown]
# Download the data, if not already on disk and load it as numpy arrays

# %%
# bring data set
website_ds = pd.read_csv('direct_csv.csv')

# verify
website_ds.groupby('label').head(2)
# Out:
#               file_name        label       x_0      x_1       x_2       x_3  \
# 0          amazon00.png       amazon  0.379437  0.36479  0.028076  0.379437
# 1          amazon01.png       amazon  0.000000  0.00000  0.000000  0.000000
# 338           bbc00.png          bbc  0.000000  0.00000  0.000000  0.000000
# 339           bbc01.png          bbc  0.000000  0.00000  0.000000  0.000000
# 682           cnn00.png          cnn  0.000000  0.00000  0.000000  0.000000
# 683           cnn01.png          cnn  0.000000  0.00000  0.000000  0.000000
# 1016         ebay00.png         ebay  0.000000  0.00000  0.000000  0.000000
# 1017         ebay01.png         ebay  0.000000  0.00000  0.000000  0.000000
# 1368      github100.png       github  0.000000  0.00000  0.000000  0.000000
# 1369      github101.png       github  0.000000  0.00000  0.000000  0.000000
# 1670       google10.png       google  0.000000  0.00000  0.000000  0.000000
# 1671       google11.png       google  0.425579  0.00000  0.425579  0.000000
# 1994     njuskalo00.png     njuskalo  0.545990  0.00000  0.000000  0.376959
# 1995     njuskalo01.png     njuskalo  0.545990  0.00000  0.000000  0.376959
# 2296      spiegel00.png      spiegel  0.000000  0.00000  0.000000  0.000000
# 2297      spiegel01.png      spiegel  0.000000  0.00000  0.000000  0.000000
# 2623  theguardian00.png  theguardian  0.000000  0.00000  0.000000  0.000000
# 2624  theguardian01.png  theguardian  0.000000  0.00000  0.000000  0.000000
# 2982      youtube00.png      youtube  0.707107  0.00000  0.000000  0.000000
# 2983      youtube01.png      youtube  0.707107  0.00000  0.000000  0.000000
#
#            x_4       x_5       x_6       x_7  ...    x_8810    x_8811  \
# 0     0.379437  0.379437  0.357514  0.379437  ...  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 338   0.000000  1.000000  0.000000  0.000000  ...  0.000000  0.000000
# 339   0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 682   0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 683   0.000000  1.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1016  0.000000  0.000000  0.000000  0.000000  ...  0.272831  0.000000
# 1017  0.000000  0.000000  0.000000  0.000000  ...  0.272831  0.000000
# 1368  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1369  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1670  0.707107  0.707107  0.000000  0.000000  ...  0.000000  0.000000
# 1671  0.000000  0.425579  0.000000  0.425579  ...  0.000000  0.000000
# 1994  0.000000  0.545990  0.306390  0.000000  ...  0.457854  0.122628
# 1995  0.000000  0.545990  0.306390  0.000000  ...  0.457854  0.122628
# 2296  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2297  0.000000  1.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2623  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2624  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2982  0.000000  0.707107  0.000000  0.000000  ...  0.000000  0.000000
# 2983  0.000000  0.707107  0.000000  0.000000  ...  0.000000  0.000000
#
#         x_8812    x_8813    x_8814    x_8815    x_8816    x_8817    x_8818  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 338   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 339   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 682   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 683   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1016  0.000000  0.000000  0.047093  0.960016  0.000000  0.000000  0.000000
# 1017  0.000000  0.000000  0.047093  0.960016  0.000000  0.000000  0.000000
# 1368  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1369  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1670  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1671  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1994  0.457854  0.122628  0.000000  0.457854  0.265905  0.457854  0.228129
# 1995  0.457854  0.122628  0.000000  0.457854  0.265905  0.457854  0.228129
# 2296  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2297  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2623  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2624  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2982  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2983  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         x_8819
# 0     0.000000
# 1     0.000000
# 338   0.000000
# 339   0.000000
# 682   0.000000
# 683   0.000000
# 1016  0.041418
# 1017  0.041418
# 1368  0.000000
# 1369  0.000000
# 1670  0.000000
# 1671  0.000000
# 1994  0.093041
# 1995  0.093041
# 2296  0.000000
# 2297  0.000000
# 2623  0.000000
# 2624  0.000000
# 2982  0.000000
# 2983  0.000000
#
# [20 rows x 8822 columns]

# %%
w, h = 256, 128
n_samples = website_ds.shape[0]

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = website_ds.drop(["label", "file_name"], axis=1)
website_features = website_ds.drop(["label", "file_name"], axis=1)
n_features = website_features.shape[1]

# the label to predict is the id of the person
y = website_ds["label"].copy()
target_names = list(set(website_ds["label"].copy()))
n_classes = len(target_names)

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# Total dataset size:
# n_samples: 3278
# n_features: 8820
# n_classes: 10

# %% [markdown]
# Split into a training set and a test and keep 25% of the data for testing.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Compute a PCA (eigenWebsites) on the Website dataset (treated as unlabeled
# dataset): unsupervised feature extraction / dimensionality reduction

# %%
n_components = 150

print(
    "Extracting the top %d eigenWebsites from %d Websites" % (n_components, X_train.shape[0])
)
t0 = time()
pca = PCA(n_components=n_components, svd_solver="randomized", whiten=True).fit(X_train)
print("done in %0.3fs" % (time() - t0))

print("Projecting the input data on the eigenWebsites orthonormal basis")
t0 = time()
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print("done in %0.3fs" % (time() - t0))
# Out:
# Extracting the top 150 eigenWebsites from 2458 Websites
# done in 2.474s
# Projecting the input data on the eigenWebsites orthonormal basis
# done in 0.268s

# %% [markdown]
# Train a SVM classification model

# %%
print("Fitting the classifier to the training set")
t0 = time()
param_grid = {
    "C": loguniform(1e3, 1e5),
    "gamma": loguniform(1e-4, 1e-1),
}
clf = RandomizedSearchCV(
    SVC(kernel="rbf", class_weight="balanced"), param_grid, n_iter=10
)
clf = clf.fit(X_train_pca, y_train)
print("done in %0.3fs" % (time() - t0))
print("Best estimator found by grid search:")
print(clf.best_estimator_)
# Out:
# Fitting the classifier to the training set
# done in 22.747s
# Best estimator found by grid search:
# SVC(C=8866.87233852254, class_weight='balanced', gamma=0.004690545393948128)

# %% [markdown]
# Quantitative evaluation of the model quality on the test set

# %%
print("Predicting Websites on the test set")
t0 = time()
y_pred = clf.predict(X_test_pca)
print("done in %0.3fs" % (time() - t0))

print(classification_report(y_test, y_pred, target_names=target_names))
ConfusionMatrixDisplay.from_estimator(
    clf, X_test_pca, y_test, display_labels=target_names, xticks_rotation="vertical"
)
plt.tight_layout()
plt.show()
# Out:
# Predicting people's names on the test set
# done in 0.365s
#               precision    recall  f1-score   support
#
#       amazon       0.94      0.93      0.94       105
#       google       0.96      0.96      0.96        98
#     njuskalo       0.93      0.97      0.95        79
#  theguardian       0.99      0.98      0.98        88
#          bbc       0.98      0.98      0.98        64
#      spiegel       1.00      0.96      0.98        80
#         ebay       1.00      1.00      1.00        64
#      youtube       0.99      0.95      0.97        81
#          cnn       0.98      0.99      0.98        90
#       github       0.96      1.00      0.98        71
#
#     accuracy                           0.97       820
#    macro avg       0.97      0.97      0.97       820
# weighted avg       0.97      0.97      0.97       820

# %% [markdown]
# plot the result of the prediction on a portion of the test set

# %%
def title(y_pred, y_test, target_names, i):
    pred_name = y_pred[i]
    true_name = y_test.to_list()[i]
    return "predicted: %s ---- true: %s" % (pred_name, true_name)


prediction_titles = [
    title(y_pred, y_test, target_names, i) for i in range(y_pred.shape[0])
]

display(prediction_titles)
# Out:
# ['predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: ebay',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: amazon',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: bbc ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: github ---- true: github',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: youtube ---- true: youtube',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: github ---- true: github',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: google',
#  'predicted: youtube ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: youtube ---- true: youtube',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: youtube ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: google',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: youtube ---- true: youtube',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: amazon ---- true: amazon',
#  'predicted: google ---- true: google',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: youtube ---- true: youtube',
#  'predicted: github ---- true: github',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: cnn',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: github ---- true: ebay',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: google ---- true: google',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: cnn',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: google ---- true: google',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: amazon ---- true: amazon',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: google ---- true: google',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: amazon ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: github ---- true: github',
#  'predicted: youtube ---- true: youtube',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: google ---- true: google',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: bbc ---- true: bbc',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: cnn ---- true: cnn',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: youtube ---- true: youtube',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: cnn ---- true: cnn',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: amazon ---- true: amazon',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: ebay ---- true: ebay',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: cnn ---- true: cnn',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: github ---- true: github',
#  'predicted: bbc ---- true: bbc',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: google ---- true: google',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: bbc ---- true: bbc',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: google',
#  'predicted: cnn ---- true: amazon',
#  'predicted: ebay ---- true: ebay',
#  'predicted: ebay ---- true: ebay',
#  'predicted: bbc ---- true: bbc',
#  'predicted: amazon ---- true: amazon',
#  'predicted: bbc ---- true: bbc',
#  'predicted: github ---- true: github',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: ebay ---- true: ebay',
#  'predicted: cnn ---- true: cnn',
#  'predicted: bbc ---- true: bbc',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: ebay ---- true: ebay',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: cnn ---- true: cnn',
#  'predicted: spiegel ---- true: spiegel',
#  'predicted: theguardian ---- true: theguardian',
#  'predicted: njuskalo ---- true: njuskalo',
#  'predicted: amazon ---- true: amazon',
#  'predicted: youtube ---- true: youtube',
#  'predicted: spiegel ---- true: spiegel']
