# %%
import pandas as pd

# bring data set
ds = pd.read_csv('img_ds.csv', index_col=[0])

# %%
# verify
ds.groupby('label').head(2)
# Out:
#             label          file_name  \
# 0          amazon       amazon00.png
# 1          amazon       amazon01.png
# 338           bbc          bbc00.png
# 339           bbc          bbc01.png
# 682           cnn          cnn00.png
# 683           cnn          cnn01.png
# 1016         ebay         ebay00.png
# 1017         ebay         ebay01.png
# 1368       github      github100.png
# 1369       github      github101.png
# 1670       google       google10.png
# 1671       google       google11.png
# 1994     njuskalo     njuskalo00.png
# 1995     njuskalo     njuskalo01.png
# 2296      spiegel      spiegel00.png
# 2297      spiegel      spiegel01.png
# 2623  theguardian  theguardian00.png
# 2624  theguardian  theguardian01.png
# 2982      youtube      youtube00.png
# 2983      youtube      youtube01.png
#
#                                               px_values
# 0     [[[ 33  25  19]\n  [ 33  25  19]\n  [ 33  25  ...
# 1     [[[255 255 255]\n  [255 255 255]\n  [255 255 2...
# ...
